# %% [markdown]
# # Brexit Polarity Tweets
#
# Twitter datasets: Brexit related tweets from pro and anti Brexit accounts January - March 2022 (Brexit leaning based on their Twitter bios)
#
# This Twitter dataset covers the January - March 2022 period and comprises tweets relating to Brexit or Europe from Twitter accounts with publicly stated Brexit positions in their bio.
#
#
# # Connecting to Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # NLTK settings and libraries import

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from sklearn.utils import shuffle
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay, f1_score
import pandas as pd
import re

# %% [markdown]
# # Datasets loading

# %%
path_anti_brexit = "/content/drive/MyDrive/Progetti/personal/brexit/TweetDataset_AntiBrexit_Jan-Mar2022.csv"
path_pro_brexit = "/content/drive/MyDrive/Progetti/personal/brexit/TweetDataset_ProBrexit_Jan-Mar2022.csv"

dataset_anti = pd.read_csv(path_anti_brexit)
dataset_pro = pd.read_csv(path_pro_brexit)

# %% [markdown]
# # Dataset Anti-Brexit

# %%
dataset_anti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210574 entries, 0 to 210573
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             210574 non-null  int64
#  1   Date                   210574 non-null  object
#  2   Headline               0 non-null       float64
#  3   URL                    210574 non-null  object
#  4   Opening Text           0 non-null       float64
#  5   Hit Sentence           210574 non-null  object
#  6   Source                 210574 non-null  object
#  7   Influencer             210574 non-null  object
#  8   Country                210574 non-null  object
#  9   Subregion              0 non-null       float64
#  10  Language               210574 non-null  object
#  11  Reach                  210574 non-null  int64
#  12  Desktop Reach          210574 non-null  int64
#  13  Mobile Reach           210574 non-null  int64
#  14  Twitter Social Echo    0 non-null       float64
#  15  Facebook Social Echo   0 non-null       float64
#  16  Reddit Social Echo     0 non-null       float64
#  17  National Viewership    210574 non-null  int64
#  18  Engagement             12929 non-null   float64
#  19  AVE                    210574 non-null  float64
#  20  Sentiment              210574 non-null  object
#  21  Key Phrases            185742 non-null  object
#  22  Input Name             210574 non-null  object
#  23  Keywords               210574 non-null  object
#  24  Twitter Authority      210459 non-null  float64
#  25  Tweet Id               210574 non-null  object
#  26  Twitter Id             210574 non-null  int64
#  27  Twitter Client         210574 non-null  object
#  28  Twitter Screen Name    210574 non-null  object
#  29  User Profile Url       210574 non-null  object
#  30  Twitter Bio            210574 non-null  object
#  31  Twitter Followers      210533 non-null  float64
#  32  Twitter Following      210571 non-null  float64
#  33  Alternate Date Format  210574 non-null  object
#  34  Time                   210574 non-null  object
#  35  State                  122570 non-null  object
#  36  City                   93146 non-null   object
#  37  Document Tags          0 non-null       float64
# dtypes: float64(12), int64(6), object(20)
# memory usage: 61.0+ MB

# %%
dataset_anti.head()
# Out:
#    Unnamed: 0                 Date  Headline  \
# 0           0  09-Jan-2022 11:58PM       NaN
# 1           1  09-Jan-2022 11:58PM       NaN
# 2           2  09-Jan-2022 11:58PM       NaN
# 3           3  09-Jan-2022 11:58PM       NaN
# 4           4  09-Jan-2022 11:57PM       NaN
#
#                                                  URL  Opening Text  \
# 0  https://twitter.com/nickynicky77551/statuses/1...           NaN
# 1  https://twitter.com/lines12345/statuses/148032...           NaN
# 2  https://twitter.com/millymoo97/statuses/148032...           NaN
# 3  https://twitter.com/ValueSurplus/statuses/1480...           NaN
# 4  https://twitter.com/Jackcdawes/statuses/148032...           NaN
#
#                                         Hit Sentence   Source  \
# 0  RT @cnapan: #JohnsonOut is now running at 218,...  Twitter
# 1  RT @Femi_Sorry: My point: Any Labour leader wh...  Twitter
# 2  RT @andy_murray: QT @Nigel_Farage: Please reco...  Twitter
# 3  RT @mikegalsworthy: We’re the first country in...  Twitter
# 4  RT @StevePeers: QT @andy_murray: Game, set and...  Twitter
#
#          Influencer         Country  Subregion  ...  \
# 0  @nickynicky77551         Unknown        NaN  ...
# 1       @lines12345         Unknown        NaN  ...
# 2       @millymoo97         Unknown        NaN  ...
# 3     @valuesurplus  United Kingdom        NaN  ...
# 4       @jackcdawes  United Kingdom        NaN  ...
#
#                              Twitter Screen Name  \
# 0                                nicky@nicky7755
# 1                                          Helen
# 2                                 seonaid mcgill
# 3  Rightwing politics is a social virus #BLM 🇵🇸🌈
# 4   Jack Dawes #FBPEGlobal #JohnsonOut #RejoinEU
#
#                       User Profile Url  \
# 0  https://twitter.com/nickynicky77551
# 1       https://twitter.com/lines12345
# 2       https://twitter.com/millymoo97
# 3     https://twitter.com/ValueSurplus
# 4       https://twitter.com/Jackcdawes
#
#                                          Twitter Bio  Twitter Followers  \
# 0  Ardent Remainer; Rejoiner now, Support NHS 💙 #...             1697.0
# 1                               Tory hating Remainer               11.0
# 2  Scottish, European, anti-Brexit, pro-EU, freel...             2129.0
# 3  Classical Cultural Marxist.\nAnti Brexit estab...             2420.0
# 4  Lover of crime & horror fiction, history, & Me...            18304.0
#
#    Twitter Following  Alternate Date Format      Time    State    City  \
# 0             2576.0            Jan 9, 2022  11:58 PM      NaN     NaN
# 1               92.0            Jan 9, 2022  11:58 PM      NaN     NaN
# 2             3880.0            Jan 9, 2022  11:58 PM      NaN     NaN
# 3             4952.0            Jan 9, 2022  11:58 PM      NaN     NaN
# 4            19889.0            Jan 9, 2022  11:57 PM  England  London
#
#    Document Tags
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 38 columns]

# %%
dataset_anti['Sentiment'].value_counts()
# Out:
# Neutral      118081
# Negative      73933
# Positive      15149
# Not Rated      3411
# Name: Sentiment, dtype: int64

# %% [markdown]
# # Building a dataset with only two columns: Hit Sentence and Sentiment

# %%
anti = dataset_anti[['Hit Sentence', 'Sentiment']].copy()
anti.describe()
# Out:
#                                              Hit Sentence Sentiment
# count                                              210574    210574
# unique                                             102442         4
# top     RT @donaldtuskEPP: Boris Johnson likens Ukrain...   Neutral
# freq                                                  260    118081

# %% [markdown]
# # Dataset Pro-Brexit

# %%
dataset_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147631 entries, 0 to 147630
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             147631 non-null  int64
#  1   Date                   147631 non-null  object
#  2   Headline               0 non-null       float64
#  3   URL                    147631 non-null  object
#  4   Opening Text           0 non-null       float64
#  5   Hit Sentence           147631 non-null  object
#  6   Source                 147631 non-null  object
#  7   Influencer             147631 non-null  object
#  8   Country                147631 non-null  object
#  9   Subregion              0 non-null       float64
#  10  Language               147631 non-null  object
#  11  Reach                  147631 non-null  int64
#  12  Desktop Reach          147631 non-null  int64
#  13  Mobile Reach           147631 non-null  int64
#  14  Twitter Social Echo    0 non-null       float64
#  15  Facebook Social Echo   0 non-null       float64
#  16  Reddit Social Echo     0 non-null       float64
#  17  National Viewership    147631 non-null  int64
#  18  Engagement             12714 non-null   float64
#  19  AVE                    147631 non-null  float64
#  20  Sentiment              147631 non-null  object
#  21  Key Phrases            127259 non-null  object
#  22  Input Name             147631 non-null  object
#  23  Keywords               147631 non-null  object
#  24  Twitter Authority      147508 non-null  float64
#  25  Tweet Id               147631 non-null  object
#  26  Twitter Id             147631 non-null  int64
#  27  Twitter Client         147631 non-null  object
#  28  Twitter Screen Name    147631 non-null  object
#  29  User Profile Url       147631 non-null  object
#  30  Twitter Bio            147631 non-null  object
#  31  Twitter Followers      147511 non-null  float64
#  32  Twitter Following      147465 non-null  float64
#  33  Alternate Date Format  147631 non-null  object
#  34  Time                   147631 non-null  object
#  35  State                  76975 non-null   object
#  36  City                   46865 non-null   object
#  37  Document Tags          0 non-null       float64
# dtypes: float64(12), int64(6), object(20)
# memory usage: 42.8+ MB

# %%
dataset_pro.head()
# Out:
#    Unnamed: 0                 Date  Headline  \
# 0           0  15-Jan-2022 11:58PM       NaN
# 1           1  15-Jan-2022 11:57PM       NaN
# 2           2  15-Jan-2022 11:56PM       NaN
# 3           3  15-Jan-2022 11:54PM       NaN
# 4           4  15-Jan-2022 11:53PM       NaN
#
#                                                  URL  Opening Text  \
# 0  https://twitter.com/dianemcgregor8/statuses/14...           NaN
# 1  http://twitter.com/DeniseMembery/statuses/1482...           NaN
# 2  https://twitter.com/007Stirling/statuses/14825...           NaN
# 3  https://twitter.com/UKleadstheworld/statuses/1...           NaN
# 4  https://twitter.com/paul_beamish/statuses/1482...           NaN
#
#                                         Hit Sentence   Source  \
# 0  RT @re11ddy: QT @sandieshoes: Do this if you v...  Twitter
# 1  RT @RickSacrop: Michael Fabricant is absolutel...  Twitter
# 2  @StokieDrew2 I do find it rich; that Tory vote...  Twitter
# 3  RT @denistmurray: Brexit Britain win as London...  Twitter
# 4  @afneil If Johnson is taken down by The Tories...  Twitter
#
#          Influencer         Country  Subregion  ...  \
# 0   @dianemcgregor8        Cameroon        NaN  ...
# 1    @DeniseMembery  United Kingdom        NaN  ...
# 2      @007stirling  United Kingdom        NaN  ...
# 3  @ukleadstheworld  United Kingdom        NaN  ...
# 4     @paul_beamish  United Kingdom        NaN  ...
#
#              Twitter Screen Name                      User Profile Url  \
# 0               Diane M McGregor    https://twitter.com/dianemcgregor8
# 1                      Denise M.  http://www.twitter.com/DeniseMembery
# 2  Finlay Stirling 🇬🇧☘️❤️🏴󠁧󠁢󠁳󠁣󠁴󠁿       https://twitter.com/007Stirling
# 3                  BestofBritish   https://twitter.com/UKleadstheworld
# 4                   Paul Beamish      https://twitter.com/paul_beamish
#
#                                          Twitter Bio  Twitter Followers  \
# 0  Veggie burger! Lover of all Animals and Nature...              122.0
# 1  🇬🇧✡️ Proud to be British. 🇬🇧   Animal lover, m...             5721.0
# 2  BRITISH/IRISH/ULSTER-SCOTS PUL\nRIGHT-WING. \n...             7219.0
# 3  GB News, Conservatives, Brexiteer, Block all ads.              700.0
# 4  Brexiteer and Shipbuilder (Plater/Welder) livi...              200.0
#
#    Twitter Following  Alternate Date Format      Time             State  \
# 0              185.0           Jan 15, 2022  11:58 PM             North
# 1             6291.0           Jan 15, 2022  11:57 PM           England
# 2             7433.0           Jan 15, 2022  11:56 PM  Northern Ireland
# 3             1014.0           Jan 15, 2022  11:54 PM               NaN
# 4              822.0           Jan 15, 2022  11:53 PM           England
#
#       City  Document Tags
# 0      NaN            NaN
# 1      NaN            NaN
# 2  Belfast            NaN
# 3      NaN            NaN
# 4      NaN            NaN
#
# [5 rows x 38 columns]

# %%
dataset_pro['Sentiment'].value_counts()
# Out:
# Neutral      85812
# Negative     44829
# Positive     14584
# Not Rated     2406
# Name: Sentiment, dtype: int64

# %% [markdown]
# # Building a dataset with only two columns: Hit Sentence and Sentiment

# %%
pro = dataset_pro[['Hit Sentence', 'Sentiment']].copy()
pro.describe()
# Out:
#                                              Hit Sentence Sentiment
# count                                              147631    147631
# unique                                              94652         4
# top     RT @FrankMcCann2: It transpires that the BBC h...   Neutral
# freq                                                  110     85812

# %% [markdown]
# # Building a merge dataset

# %%
dataset = pd.concat([anti, pro], ignore_index=True)
dataset = shuffle(dataset)
dataset
# Out:
#                                              Hit Sentence Sentiment
# 160651  RT @supertanskiii: The Bercow report was relea...   Neutral
# 47056   @BBCNews @BBCNews HOW CAN YOU EVEN THINK THIS ...   Neutral
# 39418   RT @ChrisBurn_Post: Today’s findings from the ...   Neutral
# 1003    RT @harpohap: Guardian’s Cadwalladr in court t...   Neutral
# 307588  Did they mention parties gate did they mention...   Neutral
# ...                                                   ...       ...
# 218179  RT @CatharineHoey: QT @julianHjessop: Just ano...  Negative
# 341330  RT @ubique60: @grumpygit2 1. Show us the Evide...   Neutral
# 104784  Any thoughts Truss Dorries!! Thought not!! REV...   Neutral
# 25649   QT @DeborahMeaden: Quite. ; Those quoting “ he...   Neutral
# 222628  RT @Mij_Europe: Despite his many critics, he's...   Neutral
#
# [358205 rows x 2 columns]

# %% [markdown]
# # Data cleaning

# %%
wn = WordNetLemmatizer()

def text_preprocessing(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.split()
    text = [word for word in text if word not in stopwords.words('english')]
    text = [wn.lemmatize(word) for word in text]
    text = ' '.join(text)
    return text

# %%
dataset['Hit Sentence'] = dataset['Hit Sentence'].apply(text_preprocessing)

# %%
dataset
# Out:
#                                              Hit Sentence Sentiment
# 160651  rt supertanskiii bercow report released unreda...   Neutral
# 47056   bbcnews bbcnews even think honest journalism o...   Neutral
# 39418   rt chrisburn post today finding treasury commi...   Neutral
# 1003    rt harpohap guardian cadwalladr court fight de...   Neutral
# 307588  mention party gate mention brexiteer conservat...   Neutral
# ...                                                   ...       ...
# 218179  rt catharinehoey qt julianhjessop another reas...  Negative
# 341330  rt ubique grumpygit show u evidence russian in...   Neutral
# 104784  thought truss dorries thought revealed share e...   Neutral
# 25649   qt deborahmeaden quite quoting got brexit done...   Neutral
# 222628  rt mij europe despite many critic seen many se...   Neutral
#
# [358205 rows x 2 columns]

# %% [markdown]
# # Train - validation - test split

# %%
X = dataset['Hit Sentence']
y = dataset['Sentiment']

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.2, random_state=123)
X_validation, X_test, y_validation, y_test = train_test_split(X_validation, y_validation, test_size=0.2, random_state=123)

print('Training Data : ', X_train.shape)
print('Validation Data : ', X_validation.shape)
print('Test Data : ', X_test.shape)
# Out:
# Training Data :  (286564,)
# Validation Data :  (57312,)
# Test Data :  (14329,)

# %% [markdown]
# # Feature Extraction - TFIDF - Training

# %%
from sklearn.linear_model import SGDClassifier

text_clf = Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                      ('clf', SGDClassifier(loss='perceptron'
                                            )),
                      ])

text_clf = text_clf.fit(X_train, y_train)

# %% [markdown]
# ## Validation-set performance

# %%
y_pred = text_clf.predict(X_validation)

accuracy = accuracy_score(y_validation, y_pred)
#precision = precision_score(y_validation, y_pred)
#recall = recall_score(y_validation, y_pred)
f1 = f1_score(y_validation, y_pred, average='weighted')
print('accuracy: ', accuracy)
print('f1:', f1)
# Out:
# accuracy:  0.8335252652149637
# f1: 0.832971657155422

# %% [markdown]
# ## Test-set performance

# %%
y_pred = text_clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
#precision = precision_score(y_validation, y_pred)
#recall = recall_score(y_validation, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
print('accuracy: ', accuracy)
print('f1:', f1)
# Out:
# accuracy:  0.8279014585805011
# f1: 0.8273340641445237
